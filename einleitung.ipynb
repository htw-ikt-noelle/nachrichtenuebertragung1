# %% [markdown]
# # Einleitung
#
# In diesem Modul wird schrittweise die Funktionsweise und der Aufbau eines [digitalen]() [Basisbandübertragungssystems]() besprochen. Dabei geht es vor allem darum wie eine Übertragung von Informationen von A nach B
# * möglichst schnell
# * möglichst robust
# * möglichst sicher
# * möglichst effizient
# * möglichst kostengünstig
# * ...
#
# durchgeführt werden kann.
#
# Wir betrachten dafür allerdings nur die erste (und zweite) Schicht des [ISO OSI Models](https://de.wikipedia.org/wiki/OSI-Modell), nämlich die
# * [Bitübertragungsschicht (physical layer)](https://de.wikipedia.org/wiki/OSI-Modell#Schicht_1_%E2%80%93_Bit%C3%BCbertragungsschicht_(Physical_Layer)) und die
# * [Sicherungsschicht (data link layer)](https://de.wikipedia.org/wiki/OSI-Modell#Schicht_2_%E2%80%93_Sicherungsschicht_(Data_Link_Layer)).
#
# In Veranstaltungen wie "Rechnernetze 1/2", "Digitaltechnik" und "Kommunikationsnetze" werden auch höhere Schichten des Modells betrachtet.
#
# Sie werden eher allgemeingültige / generelle Verfahren und Methoden der Nachrichtenübertragung anstatt spezifische Kommunikationssysteme kennenzulernen. Diese generellen Verfahren werden (im Zweifel leicht abgewandelt) dann in verschiedensten spezifischen Kommunikationssystemen, wie z.B. [DVB](), [Bluetooth](), [Ethernet](), [Satellitenfunk](), [Mobilfunk](), [optische Datenübertragung]() benutzt.
#
# ---
#
# Unten finden Sie ein abstraktes Blockschaltbild eines digitalen Übertragungssystems, welches als Grundlage (und als Gliederung) für diese Veranstaltung dient. Sie werden im Verlauf des Semesters nach und nach die einzelnen grünen Blöcke, ihren Aufbau sowie deren Funktion kennenlernen. Die roten Blöcke werden in der Veranstaltung "Nachrichtenübertragung 2" ausführlich besprochen.
#
# Die gestrichelten Blöcke (z.B. Quellencodierung) sind optionale Bausteine eines Übertragungssystems, während alle anderen Blöcke essentielle Bestandteile für die Übertragung sind.

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
import helpers
import schemdraw
import schemdraw.elements as elm
from schemdraw import dsp
# %config InlineBackend.figure_format = 'svg'
plt.style.use('noelle.mplstyle')

d = helpers.gen_block_diagramm()
d.draw()
#d.save('nue_block.png', dpi=400)
